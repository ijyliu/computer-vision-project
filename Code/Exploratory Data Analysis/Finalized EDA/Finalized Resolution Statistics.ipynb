# %% [markdown]
# # Resolution Statistics

# %%
# Packages
import pandas as pd
import matplotlib.pyplot as plt
import dataframe_image as dfi # NOTE: YOU MUST HAVE GOOGLE CHROME INSTALLED FOR THIS TO WORK CORRECTLY
import os

# %% [markdown]
# ## Get Observations actually in our data

# %%
# Get mapping to original location of images

# Function for loading parquet files and loading Class, harmonized_filename columns
def combine_directory_parquets_read_class_fn(directory_path):
    '''
    Combines all parquet files in a directory into a single dataframe.
    '''
    # If path does not end in a slash, add one
    if directory_path[-1] != '/':
        directory_path += '/'
    # list of files in directory
    file_list = [f for f in os.listdir(directory_path) if f.endswith('.parquet')]
    # read in all parquet files
    combined_df = pd.concat([pd.read_parquet(directory_path + f, columns=['Class', 'harmonized_filename']) for f in file_list])
    # Return combined dataframe
    return combined_df

# %%
train_data = combine_directory_parquets_read_class_fn('../../../Data/Features/All Features/train/')
test_data = combine_directory_parquets_read_class_fn('../../../Data/Features/All Features/test/')
# Combine train and test data
all_data_class_fns = pd.concat([train_data, test_data])
# Parse original filename
# Split on _orig_ and keep the second part
all_data_class_fns['Original_Filename'] = all_data_class_fns['harmonized_filename'].str.split('_orig_').str[1]
# Split on _resized and keep the first part
all_data_class_fns['Original_Filename'] = all_data_class_fns['Original_Filename'].str.split('_resized').str[0]
# replace _ with /
all_data_class_fns['Original_Filename'] = all_data_class_fns['Original_Filename'].str.replace('_', '/')
# Add .jpg to end
all_data_class_fns['Original_Filename'] = all_data_class_fns['Original_Filename'] + '.jpg'
# Replace train with cars_train/cars_train and test with cars_test/cars_test
all_data_class_fns['Original_Filename'] = all_data_class_fns['Original_Filename'].str.replace('train/', 'cars_train/cars_train/')
all_data_class_fns['Original_Filename'] = all_data_class_fns['Original_Filename'].str.replace('test/', 'cars_test/cars_test/')
all_data_class_fns
# Out:
#           Class                             harmonized_filename  \
# 0         Sedan         Sedan_train_orig_test_01516_resized.jpg
# 1           SUV          SUV_train_orig_train_00294_resized.jpg
# 2   Convertible  Convertible_train_orig_train_04236_resized.jpg
# 3        Pickup       Pickup_train_orig_train_03906_resized.jpg
# 4           SUV           SUV_train_orig_test_01344_resized.jpg
# ..          ...                                             ...
# 88        Sedan          Sedan_test_orig_test_03443_resized.jpg
# 89       Pickup        Pickup_test_orig_train_04088_resized.jpg
# 90        Sedan         Sedan_test_orig_train_03673_resized.jpg
# 91        Sedan         Sedan_test_orig_train_06616_resized.jpg
# 92  Convertible   Convertible_test_orig_train_05861_resized.jpg
#
#                   Original_Filename
# 0     cars_test/cars_test/01516.jpg
# 1   cars_train/cars_train/00294.jpg
# 2   cars_train/cars_train/04236.jpg
# 3   cars_train/cars_train/03906.jpg
# 4     cars_test/cars_test/01344.jpg
# ..                              ...
# 88    cars_test/cars_test/03443.jpg
# 89  cars_train/cars_train/04088.jpg
# 90  cars_train/cars_train/03673.jpg
# 91  cars_train/cars_train/06616.jpg
# 92  cars_train/cars_train/05861.jpg
#
# [7492 rows x 3 columns]

# %% [markdown]
# ## Get cars_annos data

# %%
# Bring in '~\Box\INFO 290T Project\Intermediate Data\cars_annos.xslx'
cars_annos = pd.read_excel('~/Box/INFO 290T Project/Intermediate Data/cars_annos.xlsx')
# Create column 'Original Filename'
# Create column based on test col
cars_annos['train_test'] = cars_annos['test'].apply(lambda x: 'cars_train/cars_train' if x == 0 else 'cars_test/cars_test')
# Original Filename is train_test + '/' + filename
cars_annos['Original_Filename'] = cars_annos['train_test'] + '/' + cars_annos['filename']
cars_annos
# Out:
#              Class   filename   x1   y1   x2   y2  old_class  test  \
# 0              SUV  00076.jpg   11   13   84   60          1     1
# 1              SUV  00457.jpg   31   20  226  119          1     1
# 2              SUV  00684.jpg  111   54  365  190          1     1
# 3              SUV  01117.jpg   45   39  729  414          1     1
# 4              SUV  01167.jpg   14   16  268  169          1     1
# ...            ...        ...  ...  ...  ...  ...        ...   ...
# 16180  Convertible  07537.jpg   47   65  249  180        196     0
# 16181  Convertible  07594.jpg   29   34  381  273        196     0
# 16182  Convertible  07846.jpg   78  289  669  633        196     0
# 16183  Convertible  07895.jpg   31    6  494  272        196     0
# 16184  Convertible  08141.jpg  138  150  706  523        196     0
#
#                       old_class_name  \
# 0         AM General Hummer SUV 2000
# 1         AM General Hummer SUV 2000
# 2         AM General Hummer SUV 2000
# 3         AM General Hummer SUV 2000
# 4         AM General Hummer SUV 2000
# ...                              ...
# 16180  smart fortwo Convertible 2012
# 16181  smart fortwo Convertible 2012
# 16182  smart fortwo Convertible 2012
# 16183  smart fortwo Convertible 2012
# 16184  smart fortwo Convertible 2012
#
#                                                  im_path  width  height  \
# 0      /Box/INFO 290T Project/Raw Data/Stanford Car D...     96      64
# 1      /Box/INFO 290T Project/Raw Data/Stanford Car D...    250     144
# 2      /Box/INFO 290T Project/Raw Data/Stanford Car D...    373     216
# 3      /Box/INFO 290T Project/Raw Data/Stanford Car D...    800     600
# 4      /Box/INFO 290T Project/Raw Data/Stanford Car D...    278     182
# ...                                                  ...    ...     ...
# 16180  /Box/INFO 290T Project/Raw Data/Stanford Car D...    262     193
# 16181  /Box/INFO 290T Project/Raw Data/Stanford Car D...    400     300
# 16182  /Box/INFO 290T Project/Raw Data/Stanford Car D...   1024     683
# 16183  /Box/INFO 290T Project/Raw Data/Stanford Car D...    500     272
# 16184  /Box/INFO 290T Project/Raw Data/Stanford Car D...    800     600
#
#        num_pixels  test_80_20             train_test  \
# 0            6144           0    cars_test/cars_test
# 1           36000           0    cars_test/cars_test
# 2           80568           0    cars_test/cars_test
# 3          480000           0    cars_test/cars_test
# 4           50596           0    cars_test/cars_test
# ...           ...         ...                    ...
# 16180       50566           0  cars_train/cars_train
# 16181      120000           0  cars_train/cars_train
# 16182      699392           0  cars_train/cars_train
# 16183      136000           0  cars_train/cars_train
# 16184      480000           0  cars_train/cars_train
#
#                      Original_Filename
# 0        cars_test/cars_test/00076.jpg
# 1        cars_test/cars_test/00457.jpg
# 2        cars_test/cars_test/00684.jpg
# 3        cars_test/cars_test/01117.jpg
# 4        cars_test/cars_test/01167.jpg
# ...                                ...
# 16180  cars_train/cars_train/07537.jpg
# 16181  cars_train/cars_train/07594.jpg
# 16182  cars_train/cars_train/07846.jpg
# 16183  cars_train/cars_train/07895.jpg
# 16184  cars_train/cars_train/08141.jpg
#
# [16185 rows x 16 columns]

# %% [markdown]
# ## Inner Join cars_annos with all_data_class_fns on 'Original_Filename'

# %%
cars_annos = cars_annos.merge(all_data_class_fns, on='Original_Filename', how='inner')
# Drop Class_x and rename Class_y to Class
cars_annos.drop(columns=['Class_x'], inplace=True)
cars_annos.rename(columns={'Class_y': 'Class'}, inplace=True)
cars_annos
# Out:
#        filename   x1   y1   x2   y2  old_class  test  \
# 0     01117.jpg   45   39  729  414          1     1
# 1     01538.jpg   32   69  487  316          1     1
# 2     01802.jpg   46  115  623  469          1     1
# 3     01887.jpg   11   60  796  535          1     1
# 4     02017.jpg   28  117  415  274          1     1
# ...         ...  ...  ...  ...  ...        ...   ...
# 7487  07500.jpg   20   27  613  413        196     0
# 7488  07594.jpg   29   34  381  273        196     0
# 7489  07846.jpg   78  289  669  633        196     0
# 7490  07895.jpg   31    6  494  272        196     0
# 7491  08141.jpg  138  150  706  523        196     0
#
#                      old_class_name  \
# 0        AM General Hummer SUV 2000
# 1        AM General Hummer SUV 2000
# 2        AM General Hummer SUV 2000
# 3        AM General Hummer SUV 2000
# 4        AM General Hummer SUV 2000
# ...                             ...
# 7487  smart fortwo Convertible 2012
# 7488  smart fortwo Convertible 2012
# 7489  smart fortwo Convertible 2012
# 7490  smart fortwo Convertible 2012
# 7491  smart fortwo Convertible 2012
#
#                                                 im_path  width  height  \
# 0     /Box/INFO 290T Project/Raw Data/Stanford Car D...    800     600
# 1     /Box/INFO 290T Project/Raw Data/Stanford Car D...    500     353
# 2     /Box/INFO 290T Project/Raw Data/Stanford Car D...    786     491
# 3     /Box/INFO 290T Project/Raw Data/Stanford Car D...    800     580
# 4     /Box/INFO 290T Project/Raw Data/Stanford Car D...    500     375
# ...                                                 ...    ...     ...
# 7487  /Box/INFO 290T Project/Raw Data/Stanford Car D...    630     420
# 7488  /Box/INFO 290T Project/Raw Data/Stanford Car D...    400     300
# 7489  /Box/INFO 290T Project/Raw Data/Stanford Car D...   1024     683
# 7490  /Box/INFO 290T Project/Raw Data/Stanford Car D...    500     272
# 7491  /Box/INFO 290T Project/Raw Data/Stanford Car D...    800     600
#
#       num_pixels  test_80_20             train_test  \
# 0         480000           0    cars_test/cars_test
# 1         176500           0    cars_test/cars_test
# 2         385926           0    cars_test/cars_test
# 3         464000           0    cars_test/cars_test
# 4         187500           0    cars_test/cars_test
# ...          ...         ...                    ...
# 7487      264600           0  cars_train/cars_train
# 7488      120000           0  cars_train/cars_train
# 7489      699392           0  cars_train/cars_train
# 7490      136000           0  cars_train/cars_train
# 7491      480000           0  cars_train/cars_train
#
#                     Original_Filename        Class  \
# 0       cars_test/cars_test/01117.jpg          SUV
# 1       cars_test/cars_test/01538.jpg          SUV
# 2       cars_test/cars_test/01802.jpg          SUV
# 3       cars_test/cars_test/01887.jpg          SUV
# 4       cars_test/cars_test/02017.jpg          SUV
# ...                               ...          ...
# 7487  cars_train/cars_train/07500.jpg  Convertible
# 7488  cars_train/cars_train/07594.jpg  Convertible
# 7489  cars_train/cars_train/07846.jpg  Convertible
# 7490  cars_train/cars_train/07895.jpg  Convertible
# 7491  cars_train/cars_train/08141.jpg  Convertible
#
#                                  harmonized_filename
# 0              SUV_train_orig_test_01117_resized.jpg
# 1              SUV_train_orig_test_01538_resized.jpg
# 2              SUV_train_orig_test_01802_resized.jpg
# 3              SUV_train_orig_test_01887_resized.jpg
# 4              SUV_train_orig_test_02017_resized.jpg
# ...                                              ...
# 7487  Convertible_train_orig_train_07500_resized.jpg
# 7488  Convertible_train_orig_train_07594_resized.jpg
# 7489  Convertible_train_orig_train_07846_resized.jpg
# 7490  Convertible_train_orig_train_07895_resized.jpg
# 7491  Convertible_train_orig_train_08141_resized.jpg
#
# [7492 rows x 17 columns]

# %% [markdown]
# ## Compute Statistics

# %%
# Summarize columns 'width' and 'height' by class
# percentile function
# https://stackoverflow.com/questions/17578115/pass-percentiles-to-pandas-agg-function
def percentile(n):
    def percentile_(x):
        return x.quantile(n / 100, interpolation='nearest')
    percentile_.__name__ = 'percentile_{:02.0f}'.format(n)
    return percentile_

# %%
# Overall num pixels by class
cars_annos.groupby('Class').agg({'num_pixels': ['count', 'mean', 'std', 'min', percentile(25), percentile(50), percentile(75), 'max']}).reset_index().sort_values(by='Class')
# Out:
#          Class num_pixels                                                     \
#                     count           mean           std     min percentile_25
# 0  Convertible       1419  548757.403805  7.926972e+05   95944        187500
# 1       Pickup        902  473148.279379  7.211021e+05  104544        187500
# 2          SUV       2057  622720.773456  1.389421e+06   96302        237900
# 3        Sedan       3114  633245.745344  1.092483e+06  102800        230250
#
#
#   percentile_50 percentile_75       max
# 0        286440        634880  12212224
# 1        307200        420938  13790208
# 2        307200        639200  42120000
# 3        307200        706552  21026304

# %%
# Describe items in selected_classes
selected_classes_description = (cars_annos[['width', 'height', 'num_pixels']].rename(columns = {'width': 'Width', 'height': 'Height', 'num_pixels': 'Number of Pixels'}).describe().T
                                                                                       .rename(columns={'count': 'Count', 'mean': 'Mean', 'std': 'Standard Deviation', 'min': 'Minimum', '25%': '25th Percentile', '50%': '50th Percentile', '75%': '75th Percentile', 'max': 'Maximum'})
                                                                                       .style
                                                                                       .format(precision=2, thousands=",", decimal=".")
                                                                                       .set_table_styles([dict(selector='th', props=[('text-align', 'center')])])
                                                                                       .set_properties(**{'text-align': 'center'}))

# Export
dfi.export(selected_classes_description, '../../../Output/Resolution Statistics/Finalized/selected_classes_description.png')

# Export to Excel
selected_classes_description.to_excel('../../../Output/Resolution Statistics/Finalized/selected_classes_description.xlsx')

selected_classes_description
# Out:
# <style type="text/css">
# #T_8b734 th {
#   text-align: center;
# }
# #T_8b734_row0_col0, #T_8b734_row0_col1, #T_8b734_row0_col2, #T_8b734_row0_col3, #T_8b734_row0_col4, #T_8b734_row0_col5, #T_8b734_row0_col6, #T_8b734_row0_col7, #T_8b734_row1_col0, #T_8b734_row1_col1, #T_8b734_row1_col2, #T_8b734_row1_col3, #T_8b734_row1_col4, #T_8b734_row1_col5, #T_8b734_row1_col6, #T_8b734_row1_col7, #T_8b734_row2_col0, #T_8b734_row2_col1, #T_8b734_row2_col2, #T_8b734_row2_col3, #T_8b734_row2_col4, #T_8b734_row2_col5, #T_8b734_row2_col6, #T_8b734_row2_col7 {
#   text-align: center;
# }
# </style>
# <table id="T_8b734">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8b734_level0_col0" class="col_heading level0 col0" >Count</th>
#       <th id="T_8b734_level0_col1" class="col_heading level0 col1" >Mean</th>
#       <th id="T_8b734_level0_col2" class="col_heading level0 col2" >Standard Deviation</th>
#       <th id="T_8b734_level0_col3" class="col_heading level0 col3" >Minimum</th>
#       <th id="T_8b734_level0_col4" class="col_heading level0 col4" >25th Percentile</th>
#       <th id="T_8b734_level0_col5" class="col_heading level0 col5" >50th Percentile</th>
#       <th id="T_8b734_level0_col6" class="col_heading level0 col6" >75th Percentile</th>
#       <th id="T_8b734_level0_col7" class="col_heading level0 col7" >Maximum</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b734_level0_row0" class="row_heading level0 row0" >Width</th>
#       <td id="T_8b734_row0_col0" class="data row0 col0" >7,492.00</td>
#       <td id="T_8b734_row0_col1" class="data row0 col1" >812.10</td>
#       <td id="T_8b734_row0_col2" class="data row0 col2" >447.70</td>
#       <td id="T_8b734_row0_col3" class="data row0 col3" >358.00</td>
#       <td id="T_8b734_row0_col4" class="data row0 col4" >584.00</td>
#       <td id="T_8b734_row0_col5" class="data row0 col5" >640.00</td>
#       <td id="T_8b734_row0_col6" class="data row0 col6" >1,024.00</td>
#       <td id="T_8b734_row0_col7" class="data row0 col7" >7,800.00</td>
#     </tr>
#     <tr>
#       <th id="T_8b734_level0_row1" class="row_heading level0 row1" >Height</th>
#       <td id="T_8b734_row1_col0" class="data row1 col0" >7,492.00</td>
#       <td id="T_8b734_row1_col1" class="data row1 col1" >564.48</td>
#       <td id="T_8b734_row1_col2" class="data row1 col2" >314.89</td>
#       <td id="T_8b734_row1_col3" class="data row1 col3" >256.00</td>
#       <td id="T_8b734_row1_col4" class="data row1 col4" >375.00</td>
#       <td id="T_8b734_row1_col5" class="data row1 col5" >480.00</td>
#       <td id="T_8b734_row1_col6" class="data row1 col6" >680.00</td>
#       <td id="T_8b734_row1_col7" class="data row1 col7" >5,400.00</td>
#     </tr>
#     <tr>
#       <th id="T_8b734_level0_row2" class="row_heading level0 row2" >Number of Pixels</th>
#       <td id="T_8b734_row2_col0" class="data row2 col0" >7,492.00</td>
#       <td id="T_8b734_row2_col1" class="data row2 col1" >595,078.80</td>
#       <td id="T_8b734_row2_col2" class="data row2 col2" >1,100,151.84</td>
#       <td id="T_8b734_row2_col3" class="data row2 col3" >95,944.00</td>
#       <td id="T_8b734_row2_col4" class="data row2 col4" >219,636.00</td>
#       <td id="T_8b734_row2_col5" class="data row2 col5" >307,200.00</td>
#       <td id="T_8b734_row2_col6" class="data row2 col6" >691,200.00</td>
#       <td id="T_8b734_row2_col7" class="data row2 col7" >42,120,000.00</td>
#     </tr>
#   </tbody>
# </table>
