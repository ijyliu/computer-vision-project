# %% [markdown]
# # Logistic Regression All_Data Feature Importance

# %%
# Packages
from Logistic_Regression_Classifier_Functions import *

# %%
# Classifier Name
classifier_name = 'Logistic Regression'

# %%
# Whether this is a sample run or not
sample_run = False

# %% [markdown]
# ## Load Test Data

# %%
train_data = combine_directory_parquets('../../../Data/Features/All Features/train')
print('all train data')
print(train_data)

if sample_run:
    train_data = train_data.sample(frac=0.01).iloc[:, 0:10]
# Out:
# all test data
#      Class                      harmonized_filename  \
# 0    Sedan   Sedan_test_orig_test_02070_resized.jpg
# 1    Sedan   Sedan_test_orig_test_05952_resized.jpg
# 2    Sedan  Sedan_test_orig_train_08046_resized.jpg
# 3      SUV     SUV_test_orig_test_00921_resized.jpg
# 4      SUV    SUV_test_orig_train_03917_resized.jpg
# ..     ...                                      ...
# 88     SUV     SUV_test_orig_test_02150_resized.jpg
# 89   Sedan  Sedan_test_orig_train_02600_resized.jpg
# 90   Sedan  Sedan_test_orig_train_07665_resized.jpg
# 91     SUV     SUV_test_orig_test_03620_resized.jpg
# 92  Pickup  Pickup_test_orig_test_01749_resized.jpg
#
#                                       image_path_blur  \
# 0   ../../../Images/test/Blurred/Sedan_test_orig_t...
# 1   ../../../Images/test/Blurred/Sedan_test_orig_t...
# 2   ../../../Images/test/Blurred/Sedan_test_orig_t...
# 3   ../../../Images/test/Blurred/SUV_test_orig_tes...
# 4   ../../../Images/test/Blurred/SUV_test_orig_tra...
# ..                                                ...
# 88  ../../../Images/test/Blurred/SUV_test_orig_tes...
# 89  ../../../Images/test/Blurred/Sedan_test_orig_t...
# 90  ../../../Images/test/Blurred/Sedan_test_orig_t...
# 91  ../../../Images/test/Blurred/SUV_test_orig_tes...
# 92  ../../../Images/test/Blurred/Pickup_test_orig_...
#
#                                    image_path_no_blur  \
# 0   ../../../Images/test/No_Blur/Sedan_test_orig_t...
# 1   ../../../Images/test/No_Blur/Sedan_test_orig_t...
# 2   ../../../Images/test/No_Blur/Sedan_test_orig_t...
# 3   ../../../Images/test/No_Blur/SUV_test_orig_tes...
# 4   ../../../Images/test/No_Blur/SUV_test_orig_tra...
# ..                                                ...
# 88  ../../../Images/test/No_Blur/SUV_test_orig_tes...
# 89  ../../../Images/test/No_Blur/Sedan_test_orig_t...
# 90  ../../../Images/test/No_Blur/Sedan_test_orig_t...
# 91  ../../../Images/test/No_Blur/SUV_test_orig_tes...
# 92  ../../../Images/test/No_Blur/Pickup_test_orig_...
#
#     ViT_Embedding_Element_0  ViT_Embedding_Element_1  ViT_Embedding_Element_2  \
# 0                 -0.219785                 0.160899                -0.216892
# 1                 -0.092094                 0.104577                -0.191433
# 2                 -0.124824                 0.123810                -0.079325
# 3                 -0.275710                 0.363630                 0.138109
# 4                 -0.077044                 0.102129                -0.017439
# ..                      ...                      ...                      ...
# 88                -0.148845                 0.120544                 0.101527
# 89                -0.113252                 0.210850                 0.130742
# 90                -0.053537                 0.362145                -0.266880
# 91                -0.260796                 0.374923                 0.052863
# 92                -0.383736                 0.049781                 0.119464
#
#     ViT_Embedding_Element_3  ViT_Embedding_Element_4  ViT_Embedding_Element_5  \
# 0                 -0.419973                 0.065086                 0.426011
# 1                 -0.470453                 0.164554                 0.383428
# 2                 -0.535870                 0.130557                 0.449481
# 3                 -0.214498                -0.124609                 0.431121
# 4                 -0.412698                 0.133949                 0.354056
# ..                      ...                      ...                      ...
# 88                -0.297986                -0.123983                 0.431480
# 89                -0.256742                -0.239382                 0.521816
# 90                -0.470987                 0.081083                 0.328001
# 91                -0.162347                -0.128699                 0.343413
# 92                -0.290881                -0.059301                 0.388186
#
#     ...  VGG_Embedding_Element_502  VGG_Embedding_Element_503  \
# 0   ...                   0.077784                   0.175107
# 1   ...                   0.061953                   0.381383
# 2   ...                   0.325484                   0.626274
# 3   ...                   0.022733                   0.084939
# 4   ...                   0.061158                   0.154853
# ..  ...                        ...                        ...
# 88  ...                   0.290321                   0.509486
# 89  ...                   0.398454                   0.628494
# 90  ...                   0.117093                   0.117663
# 91  ...                   0.016403                   0.258540
# 92  ...                   0.011524                   1.760357
#
#     VGG_Embedding_Element_504  VGG_Embedding_Element_505  \
# 0                    0.381449                   0.000000
# 1                    0.476205                   0.000000
# 2                    0.120353                   0.000000
# 3                    0.146663                   0.000000
# 4                    0.955663                   0.000000
# ..                        ...                        ...
# 88                   0.125976                   0.000000
# 89                   0.022186                   0.000000
# 90                   0.160742                   0.111290
# 91                   0.190378                   0.034143
# 92                   0.520589                   0.000000
#
#     VGG_Embedding_Element_506  VGG_Embedding_Element_507  \
# 0                    0.000000                   0.065526
# 1                    0.000000                   0.041333
# 2                    0.000000                   0.444009
# 3                    0.002123                   0.073905
# 4                    0.000000                   0.018091
# ..                        ...                        ...
# 88                   0.000000                   0.132917
# 89                   0.000000                   0.000000
# 90                   0.000000                   0.000000
# 91                   0.006423                   0.465315
# 92                   0.028385                   0.149221
#
#     VGG_Embedding_Element_508  VGG_Embedding_Element_509  \
# 0                    0.018094                   0.002819
# 1                    0.003456                   0.395730
# 2                    0.395117                   0.014483
# 3                    0.173733                   0.141122
# 4                    0.032608                   0.402419
# ..                        ...                        ...
# 88                   0.188208                   0.028514
# 89                   0.363323                   0.169784
# 90                   0.441861                   0.086545
# 91                   0.000000                   0.402545
# 92                   0.085148                   0.036407
#
#     VGG_Embedding_Element_510  VGG_Embedding_Element_511
# 0                    0.944453                   0.000000
# 1                    0.201539                   0.023107
# 2                    0.212571                   0.078218
# 3                    0.000000                   0.202087
# 4                    0.200077                   0.071901
# ..                        ...                        ...
# 88                   0.071256                   0.133997
# 89                   0.284253                   0.015856
# 90                   0.132384                   0.172020
# 91                   0.126129                   0.098992
# 92                   0.204399                   0.000000
#
# [1489 rows x 4893 columns]

# %% [markdown]
# ## Prepare Matrices

# %%
# Prepare matrices
X_train, y_train = prepare_matrices(train_data)

# %% [markdown]
# ## Load Model

# %%
# Load trained model
model = joblib.load('../../../Output/Classifier Fitting/' + classifier_name + '/All_Data Best Model.joblib')
model
# Out:
# LogisticRegression(C=0.1, class_weight='balanced', l1_ratio=1.0, max_iter=1000,
#                    multi_class='ovr', penalty='elasticnet', solver='saga')

# %% [markdown]
# ## Feature Importance

# %%
# Perform permutation importance
result = permutation_importance(model, X_train, y_train, n_repeats=100, random_state=222, n_jobs=-1)

# Put column name, mean and std in a dataframe
result = pd.DataFrame({'feature': train_data.select_dtypes(include=np.number).columns, 'mean': result.importances_mean, 'std': result.importances_std})

# Output to Excel
result.to_excel('../../../Output/Classifier Inference/' + classifier_name + '/train_permutation_importance.xlsx', index=False)

result
# Out:
#                         feature      mean       std
# 0       ViT_Embedding_Element_0  0.000000  0.000000
# 1       ViT_Embedding_Element_1  0.000940  0.001246
# 2       ViT_Embedding_Element_2  0.000000  0.000000
# 3       ViT_Embedding_Element_3  0.000537  0.000269
# 4       ViT_Embedding_Element_4  0.000000  0.000000
# ...                         ...       ...       ...
# 4884  VGG_Embedding_Element_507  0.000403  0.000329
# 4885  VGG_Embedding_Element_508  0.000000  0.000000
# 4886  VGG_Embedding_Element_509  0.001478  0.000658
# 4887  VGG_Embedding_Element_510  0.000000  0.000000
# 4888  VGG_Embedding_Element_511 -0.000537  0.000269
#
# [4889 rows x 3 columns]
