# %% [markdown]
# # Calculate Compute
#
# Normalize job times by compute used.

# %%
# Packages
import pandas as pd

# %% [markdown]
# ## Job History Data

# %%
# List of jobs we are interested in
list_of_jobs = [
                'Fit_Logistic_Regression_Classifier_All_Data',
                'Fit_Logistic_Regression_Classifier_All_Features_PCA',
                'Fit_Logistic_Regression_Classifier_Individual_Features_PCA',
                #'Fit_SVM_Classifier_All_Data',
                'Fit_SVM_Classifier_All_Features_PCA',
                'Fit_SVM_Classifier_Individual_Features_PCA',
                'fit_XGBoost_All_data',
                'fit_XGBoost_All_features_PCA',
                'fit_XGBoost_Individual_Features_PCA',
                ]

# %%
# Read pipe-delimited file '../../Data/Compute/job_history.txt' into a DataFrame
job_history = pd.read_csv('../../Data/Compute/job_history.txt', delimiter='|')
job_history
# Out:
#              JobID         JobName    Partition              State  \
# 0           385319      jupyterhub   standalone  CANCELLED by 3581
# 1     385319.batch           batch          NaN          CANCELLED
# 2    385319.extern          extern          NaN          COMPLETED
# 3           385387  transcript_ner  jsteinhardt             FAILED
# 4     385387.batch           batch          NaN             FAILED
# ..             ...             ...          ...                ...
# 730  439672.extern          extern          NaN          COMPLETED
# 731       439672.0            bash          NaN          COMPLETED
# 732         439673            bash  jsteinhardt          COMPLETED
# 733  439673.extern          extern          NaN          COMPLETED
# 734       439673.0            bash          NaN          COMPLETED
#
#                    Start                  End  AllocNodes  AllocCPUS  \
# 0    2024-03-09T14:21:23  2024-03-09T23:02:28           1          1
# 1    2024-03-09T14:21:23  2024-03-09T23:03:00           1          1
# 2    2024-03-09T14:21:23  2024-03-09T23:02:28           1          1
# 3    2024-03-09T21:07:13  2024-03-09T21:07:19           1          1
# 4    2024-03-09T21:07:13  2024-03-09T21:07:19           1          1
# ..                   ...                  ...         ...        ...
# 730  2024-04-09T21:25:33  2024-04-09T21:26:16           1          1
# 731  2024-04-09T21:25:33  2024-04-09T21:26:16           1          1
# 732  2024-04-09T21:26:33  2024-04-09T21:27:09           1          1
# 733  2024-04-09T21:26:33  2024-04-09T21:27:09           1          1
# 734  2024-04-09T21:26:33  2024-04-09T21:27:09           1          1
#
#           NodeList
# 0            arwen
# 1            arwen
# 2            arwen
# 3          saruman
# 4          saruman
# ..             ...
# 730    smokyquartz
# 731    smokyquartz
# 732  rainbowquartz
# 733  rainbowquartz
# 734  rainbowquartz
#
# [735 rows x 9 columns]

# %%
# Selected jobs - Filter job_history DataFrame to only include jobs in list_of_jobs
# require State == 'COMPLETED'
# select row of maximum End time for each job
selected_jobs = (job_history[job_history['JobName'].isin(list_of_jobs)]
                                                   .query('State == "COMPLETED"')
                                                   .groupby('JobName')
                                                   .apply(lambda x: x.loc[x['End'].idxmax()])
                                                   .reset_index(drop=True)
                                                   )
# Get time elapsed by differencing Start and End times
selected_jobs['TimeElapsed'] = pd.to_datetime(selected_jobs['End']) - pd.to_datetime(selected_jobs['Start'])
selected_jobs
# Out:
#     JobID                                            JobName    Partition  \
# 0  434001        Fit_Logistic_Regression_Classifier_All_Data  jsteinhardt
# 1  434003  Fit_Logistic_Regression_Classifier_All_Feature...  jsteinhardt
# 2  434002  Fit_Logistic_Regression_Classifier_Individual_...  jsteinhardt
# 3  435811                Fit_SVM_Classifier_All_Features_PCA  jsteinhardt
# 4  435809         Fit_SVM_Classifier_Individual_Features_PCA  jsteinhardt
# 5  434006                               fit_XGBoost_All_data  jsteinhardt
# 6  434005                       fit_XGBoost_All_features_PCA      epurdom
# 7  434004                fit_XGBoost_Individual_Features_PCA      epurdom
#
#        State                Start                  End  AllocNodes  AllocCPUS  \
# 0  COMPLETED  2024-04-07T15:19:21  2024-04-08T16:23:21           1         16
# 1  COMPLETED  2024-04-07T15:19:38  2024-04-07T19:27:29           1         16
# 2  COMPLETED  2024-04-07T15:19:30  2024-04-07T22:24:49           1         16
# 3  COMPLETED  2024-04-07T23:26:10  2024-04-08T02:21:37           1         16
# 4  COMPLETED  2024-04-07T23:25:50  2024-04-08T07:05:06           1         16
# 5  COMPLETED  2024-04-07T15:20:30  2024-04-07T19:15:20           1         16
# 6  COMPLETED  2024-04-07T15:20:20  2024-04-07T15:55:20           1         16
# 7  COMPLETED  2024-04-07T15:20:11  2024-04-07T16:02:43           1         16
#
#       NodeList     TimeElapsed
# 0    shadowfax 1 days 01:04:00
# 1  smokyquartz 0 days 04:07:51
# 2    shadowfax 0 days 07:05:19
# 3     sunstone 0 days 02:55:27
# 4     sunstone 0 days 07:39:16
# 5  smokyquartz 0 days 03:54:50
# 6        frodo 0 days 00:35:00
# 7        frodo 0 days 00:42:32

# %% [markdown]
# ## CPU data

# %%
# Load '../../Data/Compute/scf_cpus.xlsx'
scf_cpus = pd.read_excel('../../Data/Compute/scf_cpus.xlsx')
scf_cpus
# Out:
#      partition           node                             CPU model  \
# 0  jsteinhardt      shadowfax  Intel Xeon Silver 4214 CPU @ 2.20GHz
# 1  jsteinhardt         balrog   Intel Xeon Gold 5220R CPU @ 2.20GHz
# 2  jsteinhardt        saruman    Intel Xeon Gold 5320 CPU @ 2.20GHz
# 3  jsteinhardt       sunstone    Intel Xeon Gold 5218 CPU @ 2.30GHz
# 4      epurdom          frodo       AMD EPYC 7543 32-Core Processor
# 5  jsteinhardt    smokyquartz    Intel Xeon Gold 5218 CPU @ 2.30GHz
# 6  jsteinhardt  rainbowquartz    Intel Xeon Gold 5218 CPU @ 2.30GHz
#
#    passmark score
# 0           16190
# 1           33370
# 2           37558
# 3           21986
# 4           60132
# 5           21986
# 6           21986

# %% [markdown]
# ## Join on NodeList and node

# %%
job_cpu = pd.merge(selected_jobs, scf_cpus, left_on = 'NodeList', right_on = 'node', how = 'left')
job_cpu
# Out:
#     JobID                                            JobName    Partition  \
# 0  434001        Fit_Logistic_Regression_Classifier_All_Data  jsteinhardt
# 1  434003  Fit_Logistic_Regression_Classifier_All_Feature...  jsteinhardt
# 2  434002  Fit_Logistic_Regression_Classifier_Individual_...  jsteinhardt
# 3  435811                Fit_SVM_Classifier_All_Features_PCA  jsteinhardt
# 4  435809         Fit_SVM_Classifier_Individual_Features_PCA  jsteinhardt
# 5  434006                               fit_XGBoost_All_data  jsteinhardt
# 6  434005                       fit_XGBoost_All_features_PCA      epurdom
# 7  434004                fit_XGBoost_Individual_Features_PCA      epurdom
#
#        State                Start                  End  AllocNodes  AllocCPUS  \
# 0  COMPLETED  2024-04-07T15:19:21  2024-04-08T16:23:21           1         16
# 1  COMPLETED  2024-04-07T15:19:38  2024-04-07T19:27:29           1         16
# 2  COMPLETED  2024-04-07T15:19:30  2024-04-07T22:24:49           1         16
# 3  COMPLETED  2024-04-07T23:26:10  2024-04-08T02:21:37           1         16
# 4  COMPLETED  2024-04-07T23:25:50  2024-04-08T07:05:06           1         16
# 5  COMPLETED  2024-04-07T15:20:30  2024-04-07T19:15:20           1         16
# 6  COMPLETED  2024-04-07T15:20:20  2024-04-07T15:55:20           1         16
# 7  COMPLETED  2024-04-07T15:20:11  2024-04-07T16:02:43           1         16
#
#       NodeList     TimeElapsed    partition         node  \
# 0    shadowfax 1 days 01:04:00  jsteinhardt    shadowfax
# 1  smokyquartz 0 days 04:07:51  jsteinhardt  smokyquartz
# 2    shadowfax 0 days 07:05:19  jsteinhardt    shadowfax
# 3     sunstone 0 days 02:55:27  jsteinhardt     sunstone
# 4     sunstone 0 days 07:39:16  jsteinhardt     sunstone
# 5  smokyquartz 0 days 03:54:50  jsteinhardt  smokyquartz
# 6        frodo 0 days 00:35:00      epurdom        frodo
# 7        frodo 0 days 00:42:32      epurdom        frodo
#
#                               CPU model  passmark score
# 0  Intel Xeon Silver 4214 CPU @ 2.20GHz           16190
# 1    Intel Xeon Gold 5218 CPU @ 2.30GHz           21986
# 2  Intel Xeon Silver 4214 CPU @ 2.20GHz           16190
# 3    Intel Xeon Gold 5218 CPU @ 2.30GHz           21986
# 4    Intel Xeon Gold 5218 CPU @ 2.30GHz           21986
# 5    Intel Xeon Gold 5218 CPU @ 2.30GHz           21986
# 6       AMD EPYC 7543 32-Core Processor           60132
# 7       AMD EPYC 7543 32-Core Processor           60132

# %% [markdown]
# ## Compute units - compute time times num cpus times passmark score

# %%
# compute units - TimeElapsed * CPUs * passmark score
job_cpu['Units'] = job_cpu['TimeElapsed'].dt.total_seconds() * job_cpu['AllocCPUS'] * job_cpu['passmark score']
job_cpu
# Out:
#     JobID                                            JobName    Partition  \
# 0  434001        Fit_Logistic_Regression_Classifier_All_Data  jsteinhardt
# 1  434003  Fit_Logistic_Regression_Classifier_All_Feature...  jsteinhardt
# 2  434002  Fit_Logistic_Regression_Classifier_Individual_...  jsteinhardt
# 3  435811                Fit_SVM_Classifier_All_Features_PCA  jsteinhardt
# 4  435809         Fit_SVM_Classifier_Individual_Features_PCA  jsteinhardt
# 5  434006                               fit_XGBoost_All_data  jsteinhardt
# 6  434005                       fit_XGBoost_All_features_PCA      epurdom
# 7  434004                fit_XGBoost_Individual_Features_PCA      epurdom
#
#        State                Start                  End  AllocNodes  AllocCPUS  \
# 0  COMPLETED  2024-04-07T15:19:21  2024-04-08T16:23:21           1         16
# 1  COMPLETED  2024-04-07T15:19:38  2024-04-07T19:27:29           1         16
# 2  COMPLETED  2024-04-07T15:19:30  2024-04-07T22:24:49           1         16
# 3  COMPLETED  2024-04-07T23:26:10  2024-04-08T02:21:37           1         16
# 4  COMPLETED  2024-04-07T23:25:50  2024-04-08T07:05:06           1         16
# 5  COMPLETED  2024-04-07T15:20:30  2024-04-07T19:15:20           1         16
# 6  COMPLETED  2024-04-07T15:20:20  2024-04-07T15:55:20           1         16
# 7  COMPLETED  2024-04-07T15:20:11  2024-04-07T16:02:43           1         16
#
#       NodeList     TimeElapsed    partition         node  \
# 0    shadowfax 1 days 01:04:00  jsteinhardt    shadowfax
# 1  smokyquartz 0 days 04:07:51  jsteinhardt  smokyquartz
# 2    shadowfax 0 days 07:05:19  jsteinhardt    shadowfax
# 3     sunstone 0 days 02:55:27  jsteinhardt     sunstone
# 4     sunstone 0 days 07:39:16  jsteinhardt     sunstone
# 5  smokyquartz 0 days 03:54:50  jsteinhardt  smokyquartz
# 6        frodo 0 days 00:35:00      epurdom        frodo
# 7        frodo 0 days 00:42:32      epurdom        frodo
#
#                               CPU model  passmark score  \
# 0  Intel Xeon Silver 4214 CPU @ 2.20GHz           16190
# 1    Intel Xeon Gold 5218 CPU @ 2.30GHz           21986
# 2  Intel Xeon Silver 4214 CPU @ 2.20GHz           16190
# 3    Intel Xeon Gold 5218 CPU @ 2.30GHz           21986
# 4    Intel Xeon Gold 5218 CPU @ 2.30GHz           21986
# 5    Intel Xeon Gold 5218 CPU @ 2.30GHz           21986
# 6       AMD EPYC 7543 32-Core Processor           60132
# 7       AMD EPYC 7543 32-Core Processor           60132
#
#             TimePerPassmark       EstimatedLaptopTime         Units
# 0 0 days 00:00:05.573810994 0 days 15:56:11.236561242  2.337577e+10
# 1 0 days 00:00:00.676384972 0 days 01:56:02.030516796  5.231261e+09
# 2 0 days 00:00:01.576219888 0 days 04:30:24.031307184  6.610442e+09
# 3 0 days 00:00:00.478804693 0 days 01:22:08.336705049  3.703146e+09
# 4 0 days 00:00:01.253343036 0 days 03:35:00.659869548  9.693539e+09
# 5 0 days 00:00:00.640862366 0 days 01:49:56.396333238  4.956524e+09
# 6 0 days 00:00:00.034923169 0 days 00:05:59.464178517  2.020435e+09
# 7 0 days 00:00:00.042439965 0 days 00:07:16.834559745  2.455310e+09

# %% [markdown]
# ## Get compute time, roughly, if the job was run on laptop
#
# 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80 GHz
#
# Passmark: 10,293

# %%
# Add estimated laptop time as Units divided by 10,293
job_cpu['LaptopTime'] = job_cpu['Units'] / 10293
# Convert to minutes by dividing by 60
job_cpu['LaptopTime minutes'] = job_cpu['LaptopTime'] / 60
# Convert to hours by dividing by 60
job_cpu['LaptopTime hours'] = job_cpu['LaptopTime minutes'] / 60
job_cpu
# Out:
#     JobID                                            JobName    Partition  \
# 0  434001        Fit_Logistic_Regression_Classifier_All_Data  jsteinhardt
# 1  434003  Fit_Logistic_Regression_Classifier_All_Feature...  jsteinhardt
# 2  434002  Fit_Logistic_Regression_Classifier_Individual_...  jsteinhardt
# 3  435811                Fit_SVM_Classifier_All_Features_PCA  jsteinhardt
# 4  435809         Fit_SVM_Classifier_Individual_Features_PCA  jsteinhardt
# 5  434006                               fit_XGBoost_All_data  jsteinhardt
# 6  434005                       fit_XGBoost_All_features_PCA      epurdom
# 7  434004                fit_XGBoost_Individual_Features_PCA      epurdom
#
#        State                Start                  End  AllocNodes  AllocCPUS  \
# 0  COMPLETED  2024-04-07T15:19:21  2024-04-08T16:23:21           1         16
# 1  COMPLETED  2024-04-07T15:19:38  2024-04-07T19:27:29           1         16
# 2  COMPLETED  2024-04-07T15:19:30  2024-04-07T22:24:49           1         16
# 3  COMPLETED  2024-04-07T23:26:10  2024-04-08T02:21:37           1         16
# 4  COMPLETED  2024-04-07T23:25:50  2024-04-08T07:05:06           1         16
# 5  COMPLETED  2024-04-07T15:20:30  2024-04-07T19:15:20           1         16
# 6  COMPLETED  2024-04-07T15:20:20  2024-04-07T15:55:20           1         16
# 7  COMPLETED  2024-04-07T15:20:11  2024-04-07T16:02:43           1         16
#
#       NodeList     TimeElapsed    partition         node  \
# 0    shadowfax 1 days 01:04:00  jsteinhardt    shadowfax
# 1  smokyquartz 0 days 04:07:51  jsteinhardt  smokyquartz
# 2    shadowfax 0 days 07:05:19  jsteinhardt    shadowfax
# 3     sunstone 0 days 02:55:27  jsteinhardt     sunstone
# 4     sunstone 0 days 07:39:16  jsteinhardt     sunstone
# 5  smokyquartz 0 days 03:54:50  jsteinhardt  smokyquartz
# 6        frodo 0 days 00:35:00      epurdom        frodo
# 7        frodo 0 days 00:42:32      epurdom        frodo
#
#                               CPU model  passmark score  \
# 0  Intel Xeon Silver 4214 CPU @ 2.20GHz           16190
# 1    Intel Xeon Gold 5218 CPU @ 2.30GHz           21986
# 2  Intel Xeon Silver 4214 CPU @ 2.20GHz           16190
# 3    Intel Xeon Gold 5218 CPU @ 2.30GHz           21986
# 4    Intel Xeon Gold 5218 CPU @ 2.30GHz           21986
# 5    Intel Xeon Gold 5218 CPU @ 2.30GHz           21986
# 6       AMD EPYC 7543 32-Core Processor           60132
# 7       AMD EPYC 7543 32-Core Processor           60132
#
#             TimePerPassmark       EstimatedLaptopTime         Units  \
# 0 0 days 00:00:05.573810994 0 days 15:56:11.236561242  2.337577e+10
# 1 0 days 00:00:00.676384972 0 days 01:56:02.030516796  5.231261e+09
# 2 0 days 00:00:01.576219888 0 days 04:30:24.031307184  6.610442e+09
# 3 0 days 00:00:00.478804693 0 days 01:22:08.336705049  3.703146e+09
# 4 0 days 00:00:01.253343036 0 days 03:35:00.659869548  9.693539e+09
# 5 0 days 00:00:00.640862366 0 days 01:49:56.396333238  4.956524e+09
# 6 0 days 00:00:00.034923169 0 days 00:05:59.464178517  2.020435e+09
# 7 0 days 00:00:00.042439965 0 days 00:07:16.834559745  2.455310e+09
#
#      LaptopTime  LaptopTime minutes  LaptopTime hours
# 0  2.271036e+06        37850.593607        630.843227
# 1  5.082348e+05         8470.580161        141.176336
# 2  6.422269e+05        10703.782117        178.396369
# 3  3.597732e+05         5996.220655         99.937011
# 4  9.417604e+05        15696.006114        261.600102
# 5  4.815432e+05         8025.719486        133.761991
# 6  1.962922e+05         3271.535995         54.525600
# 7  2.385417e+05         3975.695171         66.261586
